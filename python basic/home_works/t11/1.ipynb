# %% [markdown]
# ### 1

# %%
a=input("eneter the word :)")
b=input("what to replace?")
al=[]
with open(r"sample.txt","r") as f:
    for i in (f.readlines()):
        lis=i.split()
        if a in lis:
            bu=lis.index(a)
            lis[bu]=b
        al.append(lis)
with open("sample.txt","a") as w:
    for s in al:
        for q in s:
            w.write(q)
            w.write(" ")
        w.write("\n")

# %%
a=[]
import random as rn
for i in range(0,10):
    a.append(rn.randint(0,1000**1000))
a
# Out:
# [...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...,
#  ...]

# %%
o=[]
p=[]
for i in a:
    if(i%2==0):
        p.append(i)
    else:
           o.append(i)    
p,o
# Out:
# ([...,
#   ...,
#   ...,
#   ...,
#   ...,
#   ...],
#  [...,
#   ...,
#   ...,
#   ...])

# %%
num = [i for i in range(100) if i % 5 == 0 or i % 6 == 0]
num
# Out:
# [0,
#  5,
#  6,
#  10,
#  12,
#  15,
#  18,
#  20,
#  24,
#  25,
#  30,
#  35,
#  36,
#  40,
#  42,
#  45,
#  48,
#  50,
#  54,
#  55,
#  60,
#  65,
#  66,
#  70,
#  72,
#  75,
#  78,
#  80,
#  84,
#  85,
#  90,
#  95,
#  96]

# %%
a=input("enter path:")
import os
import datetime
import jdatetime
with open(a,"r") as f:
     with open(r"write.txt","w") as w:
          
          w.write("the name : ")
          w.write(os.path.basename(a))
          w.write("\nlen : ")
          w.write(str(len(f.read())))
          w.write("\ndate : ")
          w.write(str(datetime.datetime.fromtimestamp(os.path.getctime(a))))
          w.write("\njdate : ")
          w.write(str(jdatetime.datetime.fromtimestamp(os.path.getctime(a))))
          w.write("\nnum of the words : ")
          f.seek(0)
          w.write(str(len((f.read()).split())))

# %%
import requests
from datetime import datetime

API = f"https://api.waqi.info/feed/tehran/?token=7dd3f625a99e9593c679c674e6ef094dc29eaa0f"
r = requests.get(API)
data = r.json()
print(data)
with open(r"ARQ.txt","w") as f:
    f.write("date : ")
    f.write(str(data["data"]["time"]["s"]))
    f.write("\nAQI : ")
    f.write(str(data["data"]["aqi"]))
# Out:
# {'status': 'ok', 'data': {'aqi': 107, 'idx': 10787, 'attributions': [{'url': 'http://aqms.doe.ir/', 'name': 'Iran National Air Quality Monitoring System - سامانه پایش کیفی هوای کشور', 'logo': 'Iran-AqccTehran.png'}, {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}], 'city': {'geo': [35.686719, 51.422419], 'name': 'Imam Khomeini, Tehran (امام خمینی تهران)', 'url': 'https://aqicn.org/city/iran/tehran/imam-khomeini', 'location': ''}, 'dominentpol': 'pm25', 'iaqi': {'co': {'v': 21}, 'dew': {'v': -2}, 'h': {'v': 11}, 'no2': {'v': 47}, 'p': {'v': 1014}, 'pm10': {'v': 67}, 'pm25': {'v': 107}, 'so2': {'v': 31}, 't': {'v': 31}, 'w': {'v': 3}, 'wg': {'v': 17.4}}, 'time': {'s': '2025-05-03 20:00:00', 'tz': '+04:30', 'v': 1746302400, 'iso': '2025-05-03T20:00:00+04:30'}, 'forecast': {'daily': {'pm10': [{'avg': 54, 'day': '2025-05-02', 'max': 61, 'min': 42}, {'avg': 70, 'day': '2025-05-03', 'max': 84, 'min': 55}, {'avg': 71, 'day': '2025-05-04', 'max': 80, 'min': 61}, {'avg
# ...
